# %%
import pickle
import numpy as np
def get_accur(filename):
    rd_accuracies = pickle.load(open("./Save/Round_accuracies/" + "Accuracy_for_" + filename + ".p", "rb"))
    return rd_accuracies

# %%
exper_name = "new"
trail_0 = get_accur(f'{exper_name}0')
trail_1 = get_accur(f'{exper_name}1')
trail_2 = get_accur(f'{exper_name}2')
trail_3 = get_accur(f'{exper_name}3')
trail_4 = get_accur(f'{exper_name}4')

# %%
trail_0.keys()
# Out:
# dict_keys(['entropy', 'kcent', 'FISH', 'BAIT', 'rand', 'DUQ', 'kmeans'])

# %%
entropy_accur_0 = trail_0['entropy']
entropy_accur_1 = trail_1['entropy']
entropy_accur_2 = trail_2['entropy']
entropy_accur_3 = trail_3['entropy']
entropy_accur_4 = trail_4['entropy']
entropy_combined = [entropy_accur_0, entropy_accur_1, entropy_accur_2, entropy_accur_3, entropy_accur_4 ]  #  entropy_accur_4

# %%
margin_accur_0 = trail_0['margin']
margin_accur_1 = trail_1['margin']
margin_accur_2 = trail_2['margin']
margin_accur_3 = trail_3['margin']
margin_accur_4 = trail_4['margin']
margin_combined = [margin_accur_0, margin_accur_1, margin_accur_2, margin_accur_3, margin_accur_4 ]  #  entropy_accur_4

# %%
lcs_accur_0 = trail_0['lcs']
lcs_accur_1 = trail_1['lcs']
lcs_accur_2 = trail_2['lcs']
lcs_accur_3 = trail_3['lcs']
lcs_accur_4 = trail_4['lcs']
lcs_combined = [lcs_accur_0, lcs_accur_1, lcs_accur_2, lcs_accur_3, lcs_accur_4 ]  #  entropy_accur_4

# %%
entropy_combined = [entropy_accur_0, entropy_accur_1, entropy_accur_2 ]  #  entropy_accur_4
# entropy_avg =[(a+b+c+d+e)/5 for a,b,c,d,e in zip(*entropy_combined)]

# %%
fish_accur_0_init = trail_0['FISH']
fish_accur_1_init = trail_1['FISH']
fish_accur_2 = trail_2['FISH']
fish_accur_3 = trail_3['FISH']
fish_accur_4 = trail_4['FISH']

# %%
#SVHN
fish_accur_0 = trail_0['FISH']
fish_accur_1 = trail_1['FISH']
fish_accur_2 = trail_2['FISH']
fish_accur_3 = trail_3['FISH']
fish_accur_4 = trail_4['FISH']
fish_combined = [fish_accur_0, fish_accur_1, fish_accur_2, fish_accur_3, fish_accur_4] # fish_accur_4

# %%
fish_accur_0 = fish_accur_0_init[:9]
fish_accur_0
# Out:
# [0.25, 0.601, 0.538, 0.5415, 0.862, 0.951, 0.97125, 0.9595, 0.94625]

# %%
fish_accur_1 = fish_accur_0_init[9:18]
fish_accur_1
# Out:
# [0.25, 0.596, 0.67775, 0.73525, 0.93125, 0.919, 0.7235, 0.96375, 0.8925]

# %%
fish_accur_4 = fish_accur_0_init[19:]
fish_accur_4
# Out:
# [0.25, 0.54175, 0.83925, 0.51925, 0.9235, 0.9475, 0.93075, 0.76975, 0.97925]

# %%
fish_accur_2 = fish_accur_1_init[:9]
fish_accur_3 = fish_accur_1_init[9:]

# %%
fish_accur_3
# Out:
# [0.255, 0.48875, 0.529, 0.52825, 0.562, 0.55675, 0.58025, 0.5955]

# %%
fish_accur_3.append(0.61)

# %%
fish_accur_3
# Out:
# [0.255, 0.48875, 0.529, 0.52825, 0.562, 0.55675, 0.58025, 0.5955, 0.61]

# %%
fish_combined = [fish_accur_0, fish_accur_1, fish_accur_2, fish_accur_3, fish_accur_4]
# fish_avg =[(a+b+c+d+e)/5 for a,b, c,d,e in zip(*fish_combined)]

# %%
rand_accur_0 = trail_0['rand']
rand_accur_1 = trail_1['rand']
rand_accur_2 = trail_2['rand']
rand_accur_3 = trail_3['rand']
rand_accur_4 = trail_4['rand']
rand_combined = [rand_accur_0, rand_accur_1, rand_accur_2, rand_accur_3, rand_accur_4]
# rand_avg = [(a+b+c+d+e)/5 for a,b,c,d,e in zip(*rand_combined)]

# %%
BAIT_accur_0 = trail_0['BAIT']
# BAIT_accur_0 = BAIT_accur_0[:9]
BAIT_accur_1 = trail_1['BAIT']
BAIT_accur_2 = trail_2['BAIT']
BAIT_accur_3 = trail_3['BAIT']
BAIT_accur_4 = trail_4['BAIT']
BAIT_combined = [BAIT_accur_0, BAIT_accur_1, BAIT_accur_2, BAIT_accur_3, BAIT_accur_4]
# BAIT_avg =[(a+b+c+d+e)/5 for a,b,c,d,e in zip(*BAIT_combined)]

# %%
BAIT_combined[0][0] = 0.25

# %%
kcent_accur_0 = trail_0['kcent']
kcent_accur_1 = trail_1['kcent']
kcent_accur_2 = trail_2['kcent']
kcent_accur_3 = trail_3['kcent']
kcent_accur_4 = trail_4['kcent']
kcent_combined = [kcent_accur_0, kcent_accur_1, kcent_accur_2, kcent_accur_3, kcent_accur_4]

# %%
import numpy as np
import matplotlib.pyplot as plt
#This plot is for only 2 trails of entropy and Fish_mask
fish_avg = np.mean(fish_combined, axis = 0)
fish_std = np.std(fish_combined, axis =0)
entropy_avg = np.mean(entropy_combined, axis = 0)
entropy_std = np.std(entropy_combined, axis =0)
x = np.arange(len(entropy_avg))
plt.plot(x, entropy_avg, label='Entropy', color='purple')
plt.fill_between(x, entropy_avg - entropy_std, entropy_avg + entropy_std, color='purple', alpha=0.1)
plt.plot(x, fish_avg, label='fish_mask', color='green')
plt.fill_between(x, fish_avg - fish_std, fish_avg + fish_std, color='green', alpha=0.1)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title('Accuracy when nQuery=70')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
#This plot is for only 3 trails of SVHN with lr=0.01
fish_avg = np.mean(fish_combined, axis = 0)
fish_std = np.std(fish_combined, axis =0)
entropy_avg = np.mean(entropy_combined, axis = 0)
entropy_std = np.std(entropy_combined, axis =0)
x = np.arange(len(entropy_avg))
plt.plot(x, entropy_avg, label='Entropy', color='purple')
plt.fill_between(x, entropy_avg - entropy_std, entropy_avg + entropy_std, color='purple', alpha=0.1)
plt.plot(x, fish_avg, label='fish_mask', color='green')
plt.fill_between(x, fish_avg - fish_std, fish_avg + fish_std, color='green', alpha=0.1)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title('Accuracy when nQuery=70')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
#This plot is for only 4 trails of new_SVHN with lr=0.001
fish_avg = np.mean(fish_combined, axis = 0)
fish_std = np.std(fish_combined, axis =0)
entropy_avg = np.mean(entropy_combined, axis = 0)
entropy_std = np.std(entropy_combined, axis =0)
x = np.arange(len(entropy_avg))
plt.plot(x, entropy_avg, label='Entropy', color='purple')
plt.fill_between(x, entropy_avg - entropy_std, entropy_avg + entropy_std, color='purple', alpha=0.1)
plt.plot(x, fish_avg, label='fish_mask', color='green')
plt.fill_between(x, fish_avg - fish_std, fish_avg + fish_std, color='green', alpha=0.1)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title('Accuracy when nQuery=70')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# This graph is for five trails of filename=new_SVHN where fish is with fish_mask and lr =0.001 and momentum 0.5
rand_avg = np.mean(rand_combined, axis=0)
rand_std = np.std(rand_combined, axis=0)

entropy_avg = np.mean(entropy_combined, axis = 0)
entropy_std = np.std(entropy_combined, axis =0)

BAIT_avg = np.mean(BAIT_combined, axis = 0)
BAIT_std = np.std(BAIT_combined, axis =0)

fish_avg = np.mean(fish_combined, axis = 0)
fish_std = np.std(fish_combined, axis =0)

kcent_avg = np.mean(kcent_combined, axis = 0)
kcent_std = np.std(kcent_combined, axis =0)
x = np.arange(len(rand_avg))
# Define the x-values
x_values = [15, 85, 155, 225, 295, 365, 435, 505, 575, 645, 715, 785, 855, 925]
plt.xticks(range(len(x_values)), x_values)

# Create the plot with a solid line
plt.plot(x, rand_avg, label='Random', color='blue')
plt.fill_between(x, rand_avg - rand_std, rand_avg + rand_std, color='blue', alpha=0.1)

plt.plot(x, BAIT_avg, label='BAIT', color='red')
plt.fill_between(x, BAIT_avg - BAIT_std, BAIT_avg + BAIT_std, color='red', alpha=0.1)

plt.plot(x, entropy_avg, label='Entropy', color='purple')
plt.fill_between(x, entropy_avg - entropy_std, entropy_avg + entropy_std, color='purple', alpha=0.1)

plt.plot(x, fish_avg, label='Fisher_mask', color='green')
plt.fill_between(x, fish_avg - fish_std, fish_avg + fish_std, color='green', alpha=0.1)

plt.plot(x, kcent_avg, label='kcent', color='brown')
plt.fill_between(x, kcent_avg - kcent_std, kcent_avg + kcent_std, color='brown', alpha=0.1)

plt.xlabel('Number of Labels')
plt.ylabel('Accuracy')
# plt.title('Accuracy for 5000 images averaged over 5 trails')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# This graph is for five trails of filename=new_SVHN_0.001_0.3 where fish is with fish_mask and lr =0.001 and momentum 0.3
rand_avg = np.mean(rand_combined, axis=0)
rand_std = np.std(rand_combined, axis=0)

entropy_avg = np.mean(entropy_combined, axis = 0)
entropy_std = np.std(entropy_combined, axis =0)

BAIT_avg = np.mean(BAIT_combined, axis = 0)
BAIT_std = np.std(BAIT_combined, axis =0)

fish_avg = np.mean(fish_combined, axis = 0)
fish_std = np.std(fish_combined, axis =0)

kcent_avg = np.mean(kcent_combined, axis = 0)
kcent_std = np.std(kcent_combined, axis =0)
x = np.arange(len(rand_avg))
# Define the x-values
x_values = [15, 85, 155, 225, 295, 365, 435, 505, 575, 645, 715, 785, 855, 925]
plt.xticks(range(len(x_values)), x_values)

# Create the plot with a solid line
plt.plot(x, rand_avg, label='Random', color='blue')
plt.fill_between(x, rand_avg - rand_std, rand_avg + rand_std, color='blue', alpha=0.1)

plt.plot(x, BAIT_avg, label='BAIT', color='red')
plt.fill_between(x, BAIT_avg - BAIT_std, BAIT_avg + BAIT_std, color='red', alpha=0.1)

plt.plot(x, entropy_avg, label='Entropy', color='purple')
plt.fill_between(x, entropy_avg - entropy_std, entropy_avg + entropy_std, color='purple', alpha=0.1)

plt.plot(x, fish_avg, label='Fisher_mask', color='green')
plt.fill_between(x, fish_avg - fish_std, fish_avg + fish_std, color='green', alpha=0.1)

plt.plot(x, kcent_avg, label='kcent', color='brown')
plt.fill_between(x, kcent_avg - kcent_std, kcent_avg + kcent_std, color='brown', alpha=0.1)

plt.xlabel('Number of Labels')
plt.ylabel('Accuracy')
# plt.title('Accuracy for 5000 images averaged over 5 trails')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
#This plot is for 4 trails of entropy and Fish_mask
fish_avg = np.mean(fish_combined, axis = 0)
fish_std = np.std(fish_combined, axis =0)
entropy_avg = np.mean(entropy_combined, axis = 0)
entropy_std = np.std(entropy_combined, axis =0)
x = np.arange(len(entropy_avg))
plt.plot(x, entropy_avg, label='Entropy', color='purple')
plt.fill_between(x, entropy_avg - entropy_std, entropy_avg + entropy_std, color='purple', alpha=0.1)
plt.plot(x, fish_avg, label='fish_mask', color='green')
plt.fill_between(x, fish_avg - fish_std, fish_avg + fish_std, color='green', alpha=0.1)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title('Accuracy when nQuery=70')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
#This plot is for 5 trails of entropy and Fish_mask
fish_avg = np.mean(fish_combined, axis = 0)
fish_std = np.std(fish_combined, axis =0)
entropy_avg = np.mean(entropy_combined, axis = 0)
entropy_std = np.std(entropy_combined, axis =0)
x = np.arange(len(entropy_avg))
plt.plot(x, entropy_avg, label='Entropy', color='purple')
plt.fill_between(x, entropy_avg - entropy_std, entropy_avg + entropy_std, color='purple', alpha=0.1)
plt.plot(x, fish_avg, label='fish_mask', color='green')
plt.fill_between(x, fish_avg - fish_std, fish_avg + fish_std, color='green', alpha=0.1)
plt.xlabel('Rounds')
plt.ylabel('Accuracy')
plt.title('Accuracy when nQuery=70')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# This graph is for filename=lr_0.001 where fish is with fish_mask
rand_avg = np.mean(rand_combined, axis=0)
rand_std = np.std(rand_combined, axis=0)

entropy_avg = np.mean(entropy_combined, axis = 0)
entropy_std = np.std(entropy_combined, axis =0)

BAIT_avg = np.mean(BAIT_combined, axis = 0)
BAIT_std = np.std(BAIT_combined, axis =0)


fish_avg = np.mean(fish_combined, axis = 0)
fish_std = np.std(fish_combined, axis =0)

x = np.arange(len(rand_avg))
# Define the x-values
x_values = [15, 85, 155, 225, 295, 365, 435, 505, 575]
plt.xticks(range(len(x_values)), x_values)

# Create the plot with a solid line
plt.plot(x, rand_avg, label='Random', color='blue')
plt.fill_between(x, rand_avg - rand_std, rand_avg + rand_std, color='blue', alpha=0.1)

plt.plot(x, BAIT_avg, label='BAIT', color='red')
plt.fill_between(x, BAIT_avg - BAIT_std, BAIT_avg + BAIT_std, color='red', alpha=0.1)

plt.plot(x, entropy_avg, label='Entropy', color='purple')
plt.fill_between(x, entropy_avg - entropy_std, entropy_avg + entropy_std, color='purple', alpha=0.1)

plt.plot(x, fish_avg, label='Fisher_mask', color='green')
plt.fill_between(x, fish_avg - fish_std, fish_avg + fish_std, color='green', alpha=0.1)


# Add labels and legend
plt.xlabel('Active Learning Rounds')
plt.ylabel('Accuracy')
# plt.title('Accuracy for 5000 images averaged over 5 trails')
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'serif'

# This graph is for filename=lr_0.001 where fish is with fish_mask
rand_avg = np.mean(rand_combined, axis=0)
rand_std = np.std(rand_combined, axis=0)

entropy_avg = np.mean(entropy_combined, axis = 0)
entropy_std = np.std(entropy_combined, axis =0)

BAIT_avg = np.mean(BAIT_combined, axis = 0)
BAIT_std = np.std(BAIT_combined, axis =0)


fish_avg = np.mean(fish_combined, axis = 0)
fish_std = np.std(fish_combined, axis =0)

x = np.arange(len(rand_avg))
# Define the x-values
x_values = [15, 85, 155, 225, 295, 365, 435, 505, 575]


# Create the plot with a solid line
plt.plot(x, rand_avg, label='Random', color='blue')
plt.fill_between(x, rand_avg - rand_std, rand_avg + rand_std, color='blue', alpha=0.1)

plt.plot(x, BAIT_avg, label='BAIT', color='red')
plt.fill_between(x, BAIT_avg - BAIT_std, BAIT_avg + BAIT_std, color='red', alpha=0.1)

plt.plot(x, entropy_avg, label='Entropy', color='purple')
plt.fill_between(x, entropy_avg - entropy_std, entropy_avg + entropy_std, color='purple', alpha=0.1)

plt.plot(x, fish_avg, label='Fisher_mask', color='green')
plt.fill_between(x, fish_avg - fish_std, fish_avg + fish_std, color='green', alpha=0.1)


# Add labels and legend
plt.xlabel('Number of labels', fontsize=12, fontfamily='serif')
plt.ylabel('Accuracy', fontsize=12, fontfamily='serif')
plt.xticks(range(len(x_values)), x_values)
# plt.title('Accuracy for 5000 images averaged over 5 trails')
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'serif'

# This graph is for filename=MNIST where fish is with fish_mask
rand_avg = np.mean(rand_combined, axis=0)
rand_std = np.std(rand_combined, axis=0)

entropy_avg = np.mean(entropy_combined, axis = 0)
entropy_std = np.std(entropy_combined, axis =0)

BAIT_avg = np.mean(BAIT_combined, axis = 0)
BAIT_std = np.std(BAIT_combined, axis =0)


fish_avg = np.mean(fish_combined, axis = 0)
fish_std = np.std(fish_combined, axis =0)

x = np.arange(len(rand_avg))
# Define the x-values
x_values = [15, 85, 155, 225, 295, 365, 435, 505, 575]


# Create the plot with a solid line
plt.plot(x, rand_avg, label='Random', color='blue')
plt.fill_between(x, rand_avg - rand_std, rand_avg + rand_std, color='blue', alpha=0.1)

plt.plot(x, BAIT_avg, label='BAIT', color='red')
plt.fill_between(x, BAIT_avg - BAIT_std, BAIT_avg + BAIT_std, color='red', alpha=0.1)

plt.plot(x, entropy_avg, label='Entropy', color='purple')
plt.fill_between(x, entropy_avg - entropy_std, entropy_avg + entropy_std, color='purple', alpha=0.1)

plt.plot(x, fish_avg, label='Fisher_mask(Ours)', color='green')
plt.fill_between(x, fish_avg - fish_std, fish_avg + fish_std, color='green', alpha=0.1)


# Add labels and legend
plt.xlabel('Number of labels', fontsize=12, fontfamily='serif')
plt.ylabel('Accuracy', fontsize=12, fontfamily='serif')
plt.xticks(range(len(x_values)), x_values)
# plt.title('Accuracy for 5000 images averaged over 5 trails')
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'serif'

# This graph is for filename=MNIST where fish is with fish_mask and kcent algorithm
rand_avg = np.mean(rand_combined, axis=0)
rand_std = np.std(rand_combined, axis=0)

entropy_avg = np.mean(entropy_combined, axis = 0)
entropy_std = np.std(entropy_combined, axis =0)

BAIT_avg = np.mean(BAIT_combined, axis = 0)
BAIT_std = np.std(BAIT_combined, axis =0)


fish_avg = np.mean(fish_combined, axis = 0)
fish_std = np.std(fish_combined, axis =0)

kcent_avg = np.mean(kcent_combined, axis = 0)
kcent_std = np.std(kcent_combined, axis =0)

x = np.arange(len(rand_avg))
# Define the x-values
x_values = [15, 85, 155, 225, 295, 365, 435, 505, 575]


# Create the plot with a solid line
plt.plot(x, rand_avg, label='Random', color='blue')
plt.fill_between(x, rand_avg - rand_std, rand_avg + rand_std, color='blue', alpha=0.1)

plt.plot(x, BAIT_avg, label='BAIT', color='red')
plt.fill_between(x, BAIT_avg - BAIT_std, BAIT_avg + BAIT_std, color='red', alpha=0.1)

plt.plot(x, entropy_avg, label='Entropy', color='purple')
plt.fill_between(x, entropy_avg - entropy_std, entropy_avg + entropy_std, color='purple', alpha=0.1)

plt.plot(x, fish_avg, label='Fisher_mask', color='green')
plt.fill_between(x, fish_avg - fish_std, fish_avg + fish_std, color='green', alpha=0.1)

plt.plot(x, kcent_avg, label='kcent', color='black')
plt.fill_between(x, kcent_avg - kcent_std, kcent_avg + kcent_std, color='black', alpha=0.1)


# Add labels and legend
plt.xlabel('Number of labels', fontsize=12, fontfamily='serif')
plt.ylabel('Accuracy', fontsize=12, fontfamily='serif')
plt.xticks(range(len(x_values)), x_values)
# plt.title('Accuracy for 5000 images averaged over 5 trails')
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# This graph is for filename=CI_new where fish is with fish_mask which is with the new hyperparameters like 
#   if type(optimizer) == int: optimizer = optim.Adam(self.clf.parameters(),lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0)   #previously it was 0

rand_avg = np.mean(rand_combined, axis=0)
rand_std = np.std(rand_combined, axis=0)

entropy_avg = np.mean(entropy_combined, axis = 0)
entropy_std = np.std(entropy_combined, axis =0)

BAIT_avg = np.mean(BAIT_combined, axis = 0)
BAIT_std = np.std(BAIT_combined, axis =0)


fish_avg = np.mean(fish_combined, axis = 0)
fish_std = np.std(fish_combined, axis =0)

x = np.arange(len(rand_avg))
# Define the x-values
x_values = [15, 85, 155, 225, 295, 365, 435, 505, 575, 645, 715, 785, 855, 925]
plt.xticks(range(len(x_values)), x_values)

# Create the plot with a solid line
plt.plot(x, rand_avg, label='Random', color='blue')
plt.fill_between(x, rand_avg - rand_std, rand_avg + rand_std, color='blue', alpha=0.1)

plt.plot(x, BAIT_avg, label='BAIT', color='red')
plt.fill_between(x, BAIT_avg - BAIT_std, BAIT_avg + BAIT_std, color='red', alpha=0.1)

plt.plot(x, entropy_avg, label='Entropy', color='purple')
plt.fill_between(x, entropy_avg - entropy_std, entropy_avg + entropy_std, color='purple', alpha=0.1)

plt.plot(x, fish_avg, label='Fisher_mask', color='green')
plt.fill_between(x, fish_avg - fish_std, fish_avg + fish_std, color='green', alpha=0.1)


# Add labels and legend
plt.xlabel('Number of Labels')
plt.ylabel('Accuracy')
# plt.title('Accuracy for 5000 images averaged over 5 trails')
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# This graph is for filename=CI_pct_0.001_new which happens a lot quicker and with the new hyperparameters like 
#   if type(optimizer) == int: optimizer = optim.Adam(self.clf.parameters(),lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0)   #previously it was 0
rand_avg = np.mean(rand_combined, axis=0)
rand_std = np.std(rand_combined, axis=0)

entropy_avg = np.mean(entropy_combined, axis = 0)
entropy_std = np.std(entropy_combined, axis =0)

# BAIT_avg = np.mean(BAIT_combined, axis = 0)
# BAIT_std = np.std(BAIT_combined, axis =0)


fish_avg = np.mean(fish_combined, axis = 0)
fish_std = np.std(fish_combined, axis =0)

x = np.arange(len(rand_avg))
# Define the x-values
x_values = [15, 85, 155, 225, 295, 365, 435, 505, 575, 645, 715, 785, 855, 925]
plt.xticks(range(len(x_values)), x_values)

# Create the plot with a solid line
plt.plot(x, rand_avg, label='Random', color='blue')
plt.fill_between(x, rand_avg - rand_std, rand_avg + rand_std, color='blue', alpha=0.1)

# plt.plot(x, BAIT_avg, label='BAIT', color='red')
# plt.fill_between(x, BAIT_avg - BAIT_std, BAIT_avg + BAIT_std, color='red', alpha=0.1)

plt.plot(x, entropy_avg, label='Entropy', color='purple')
plt.fill_between(x, entropy_avg - entropy_std, entropy_avg + entropy_std, color='purple', alpha=0.1)

plt.plot(x, fish_avg, label='Fisher_mask', color='green')
plt.fill_between(x, fish_avg - fish_std, fish_avg + fish_std, color='green', alpha=0.1)
plt.xlabel('Number of Labels')
plt.ylabel('Accuracy')
# plt.title('Accuracy for 5000 images averaged over 5 trails')
plt.legend()
plt.show()

# %%
st = 250
end = 5750
inc = 250
cur = st
li = []
while cur < end:
    
    cur += inc
    li.append(cur)

print(li)
# Out:
# [500, 750, 1000, 1250, 1500, 1750, 2000, 2250, 2500, 2750, 3000, 3250, 3500, 3750, 4000, 4250, 4500, 4750, 5000, 5250, 5500, 5750]

# %%
from resnet import ResNet18

# %%
model = ResNet18()

# %%
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=128, out_features=10, bias=False)
# )

# %%
import numpy as np
import matplotlib.pyplot as plt

# This graph is for 3 trails of filename=new where fish is with fish_mask which is with the new hyperparameters like 
#   if type(optimizer) == int: optimizer = optim.Adam(self.clf.parameters(),lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0)   #previously it was 0

rand_avg = np.mean(rand_combined, axis=0)
rand_std = np.std(rand_combined, axis=0)

entropy_avg = np.mean(entropy_combined, axis = 0)
entropy_std = np.std(entropy_combined, axis =0)

BAIT_avg = np.mean(BAIT_combined, axis = 0)
BAIT_std = np.std(BAIT_combined, axis =0)


fish_avg = np.mean(fish_combined, axis = 0)
fish_std = np.std(fish_combined, axis =0)

kcent_avg = np.mean(kcent_combined, axis = 0)
kcent_std = np.std(kcent_combined, axis = 0)

margin_avg = np.mean(margin_combined, axis = 0)
margin_std = np.std(margin_combined, axis=0)

lcs_avg = np.mean(lcs_combined, axis = 0)
lcs_std = np.std(lcs_combined, axis = 0)

x = np.arange(len(rand_avg))
# Define the x-values
x_values = [250, 500, 750, 1000, 1250, 1500, 1750, 2000, 2250, 2500, 2750, 3000, 3250, 3500, 3750, 4000, 4250, 4500, 4750, 5000, 5250, 5500, 5750]
plt.xticks(range(len(x_values)), x_values, rotation=45)

# Create the plot with a solid line
plt.plot(x, rand_avg, label='Random', color='blue')
plt.fill_between(x, rand_avg - rand_std, rand_avg + rand_std, color='blue', alpha=0.1)

plt.plot(x, BAIT_avg, label='BAIT', color='red')
plt.fill_between(x, BAIT_avg - BAIT_std, BAIT_avg + BAIT_std, color='red', alpha=0.1)

plt.plot(x, entropy_avg, label='Entropy', color='purple')
plt.fill_between(x, entropy_avg - entropy_std, entropy_avg + entropy_std, color='purple', alpha=0.1)

plt.plot(x, fish_avg, label='Fisher_mask', color='green')
plt.fill_between(x, fish_avg - fish_std, fish_avg + fish_std, color='green', alpha=0.1)

plt.plot(x, margin_avg, label='margin', color='black')
plt.fill_between(x, margin_avg - margin_std, margin_avg + margin_std, color='black', alpha=0.1)

plt.plot(x, kcent_avg, label='kcenter', color='orange')
plt.fill_between(x, kcent_avg - kcent_std, kcent_avg + kcent_std, color='orange', alpha=0.1)

# plt.plot(x, fish_avg, label='Fisher_mask', color='green')
# plt.fill_between(x, fish_avg - fish_std, fish_avg + fish_std, color='green', alpha=0.1)


# Add labels and legend
plt.xlabel('Number of Labels')
plt.ylabel('Accuracy')
# plt.title('Accuracy for 5000 images averaged over 5 trails')
plt.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# This graph is for 5 trails of filename=new where fish is with fish_mask which is with the new hyperparameters like 
#   if type(optimizer) == int: optimizer = optim.Adam(self.clf.parameters(),lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0)   #previously it was 0

rand_avg = np.mean(rand_combined, axis=0)
rand_std = np.std(rand_combined, axis=0)

entropy_avg = np.mean(entropy_combined, axis = 0)
entropy_std = np.std(entropy_combined, axis =0)

BAIT_avg = np.mean(BAIT_combined, axis = 0)
BAIT_std = np.std(BAIT_combined, axis =0)


fish_avg = np.mean(fish_combined, axis = 0)
fish_std = np.std(fish_combined, axis =0)

kcent_avg = np.mean(kcent_combined, axis = 0)
kcent_std = np.std(kcent_combined, axis = 0)

margin_avg = np.mean(margin_combined, axis = 0)
margin_std = np.std(margin_combined, axis=0)

lcs_avg = np.mean(lcs_combined, axis = 0)
lcs_std = np.std(lcs_combined, axis = 0)

x = np.arange(len(rand_avg))
# Define the x-values
x_values = [250, 500, 750, 1000, 1250, 1500, 1750, 2000, 2250, 2500, 2750, 3000, 3250, 3500, 3750, 4000, 4250, 4500, 4750, 5000, 5250, 5500, 5750]
plt.xticks(range(len(x_values)), x_values, rotation=45)

# Create the plot with a solid line
plt.plot(x, rand_avg, label='Random', color='blue')
plt.fill_between(x, rand_avg - rand_std, rand_avg + rand_std, color='blue', alpha=0.1)

plt.plot(x, BAIT_avg, label='BAIT', color='red')
plt.fill_between(x, BAIT_avg - BAIT_std, BAIT_avg + BAIT_std, color='red', alpha=0.1)

plt.plot(x, entropy_avg, label='Entropy', color='purple')
plt.fill_between(x, entropy_avg - entropy_std, entropy_avg + entropy_std, color='purple', alpha=0.1)

plt.plot(x, fish_avg, label='Fisher_mask', color='green')
plt.fill_between(x, fish_avg - fish_std, fish_avg + fish_std, color='green', alpha=0.1)

plt.plot(x, margin_avg, label='margin', color='black')
plt.fill_between(x, margin_avg - margin_std, margin_avg + margin_std, color='black', alpha=0.1)

plt.plot(x, kcent_avg, label='kcenter', color='orange')
plt.fill_between(x, kcent_avg - kcent_std, kcent_avg + kcent_std, color='orange', alpha=0.1)

# plt.plot(x, fish_avg, label='Fisher_mask', color='green')
# plt.fill_between(x, fish_avg - fish_std, fish_avg + fish_std, color='green', alpha=0.1)

plt.xlabel('Number of labels', fontsize=12, fontfamily='serif')
plt.ylabel('Accuracy', fontsize=12, fontfamily='serif')
# plt.title('Accuracy for 5000 images averaged over 5 trails')
plt.legend()

# Show the plot
plt.show()
